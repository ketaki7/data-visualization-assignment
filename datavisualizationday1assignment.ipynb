# %% [markdown]
# <a href="https://colab.research.google.com/github/ketaki7/data-visualization-assignment/blob/main/datavisualizationday1assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#assignment no 1

x=np.arange(0,10)
y=x*x
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)

# %%
#assignment 2

days=[1,2,3,4,5,6,7]
sales_1=[160,150,140,145,175,165,180]
plt.xlabel("Days")
plt.ylabel("sales")
plt.plot(days,sales_1,color="black",marker="o", linewidth=1, markersize=6)
